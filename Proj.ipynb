# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Metro_Interstate_Traffic_Volume.csv")
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.isna().sum()
# Out:
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64

# %%
df.dtypes
# Out:
# holiday                 object
# temp                   float64
# rain_1h                float64
# snow_1h                float64
# clouds_all               int64
# weather_main            object
# weather_description     object
# date_time               object
# traffic_volume           int64
# dtype: object

# %%
df1=df["holiday"].value_counts()

# %%
plt.barh(df1.index,df1.values)
# Out:
# <BarContainer object of 11 artists>

# %%
df["holiday"].isna().sum()
# Out:
# np.int64(48143)

# %%
df["holiday"].isna().sum()
# Out:
# np.int64(48143)

# %%
df.dtypes
# Out:
# holiday                 object
# temp                   float64
# rain_1h                float64
# snow_1h                float64
# clouds_all               int64
# weather_main            object
# weather_description     object
# date_time               object
# traffic_volume           int64
# dtype: object

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
df2=df['weather_main'].value_counts
df2
# Out:
# <bound method IndexOpsMixin.value_counts of 0              Clouds
# 1              Clouds
# 2              Clouds
# 3              Clouds
# 4              Clouds
#              ...
# 48199          Clouds
# 48200          Clouds
# 48201    Thunderstorm
# 48202          Clouds
# 48203          Clouds
# Name: weather_main, Length: 48204, dtype: object>

# %%
df3=df['weather_description'].value_counts
df3
# Out:
# <bound method IndexOpsMixin.value_counts of 0              scattered clouds
# 1                 broken clouds
# 2               overcast clouds
# 3               overcast clouds
# 4                 broken clouds
#                   ...
# 48199             broken clouds
# 48200           overcast clouds
# 48201    proximity thunderstorm
# 48202           overcast clouds
# 48203           overcast clouds
# Name: weather_description, Length: 48204, dtype: object>

# %%
df.isna().sum()
# Out:
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64

# %%
df["is_holiday"] = df["holiday"].apply(lambda x:0 if x == "None" else 1)

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume  is_holiday
# 0    scattered clouds  2012-10-02 09:00:00            5545           1
# 1       broken clouds  2012-10-02 10:00:00            4516           1
# 2     overcast clouds  2012-10-02 11:00:00            4767           1
# 3     overcast clouds  2012-10-02 12:00:00            5026           1
# 4       broken clouds  2012-10-02 13:00:00            4918           1

# %%
df.drop(['holiday'],axis =1)
# Out:
#          temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0      288.28      0.0      0.0          40        Clouds
# 1      289.36      0.0      0.0          75        Clouds
# 2      289.58      0.0      0.0          90        Clouds
# 3      290.13      0.0      0.0          90        Clouds
# 4      291.14      0.0      0.0          75        Clouds
# ...       ...      ...      ...         ...           ...
# 48199  283.45      0.0      0.0          75        Clouds
# 48200  282.76      0.0      0.0          90        Clouds
# 48201  282.73      0.0      0.0          90  Thunderstorm
# 48202  282.09      0.0      0.0          90        Clouds
# 48203  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume  is_holiday
# 0            scattered clouds  2012-10-02 09:00:00            5545           1
# 1               broken clouds  2012-10-02 10:00:00            4516           1
# ...

# %%
df["date_time"] = pd.to_datetime(df["date_time"])

# %%
df["date_time"]
# Out:
# 0       2012-10-02 09:00:00
# 1       2012-10-02 10:00:00
# 2       2012-10-02 11:00:00
# 3       2012-10-02 12:00:00
# 4       2012-10-02 13:00:00
#                 ...
# 48199   2018-09-30 19:00:00
# 48200   2018-09-30 20:00:00
# 48201   2018-09-30 21:00:00
# 48202   2018-09-30 22:00:00
# 48203   2018-09-30 23:00:00
# Name: date_time, Length: 48204, dtype: datetime64[ns]

# %%
df["hour"] = df["date_time"].dt.hour
df["month"] = df["date_time"].dt.month
df["weekend"] = df["date_time"].dt.weekday

# %%
df["weekend"].value_counts()
# Out:
# weekend
# 0    7072
# 2    6930
# 6    6872
# 1    6846
# 4    6836
# 5    6831
# 3    6817
# Name: count, dtype: int64

# %%
df["is_weekend"] = df["weekend"].apply(lambda x:0 if x<5 else 1)

# %%
df["is_weekend"].value_counts()
# Out:
# is_weekend
# 0    34501
# 1    13703
# Name: count, dtype: int64

# %%
df["traffic_status"] = df["traffic_volume"].apply(lambda x:0 if x<4000 else 1)
df["traffic_status"].value_counts()
# Out:
# traffic_status
# 0    27265
# 1    20939
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume', 'is_holiday',
#        'hour', 'month', 'weekend', 'is_weekend', 'traffic_status'],
#       dtype='object')

# %%
df["snow_1hr"] = df["snow_1h"].apply(lambda x:0 if x<1 else 1)
df["snow_1hr"].value_counts()
# Out:
# snow_1hr
# 0    48204
# Name: count, dtype: int64

# %%
df["snow_1h"].value_counts()
# Out:
# snow_1h
# 0.00    48141
# 0.05       14
# 0.06       12
# 0.51        6
# 0.10        6
# 0.25        6
# 0.13        6
# 0.32        5
# 0.17        3
# 0.44        2
# 0.08        2
# 0.21        1
# Name: count, dtype: int64

# %%
df["rain_1hr"] = df["rain_1h"].apply(lambda x:0 if x<1 else 1)

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume', 'is_holiday',
#        'hour', 'month', 'weekend', 'is_weekend', 'traffic_status', 'snow_1hr',
#        'rain_1hr'],
#       dtype='object')

# %%
features = [
    'temp',
    'clouds_all',
    'rain_1hr',
    'snow_1hr',
    'weather_main',
    'hour',
    'month',
    'is_weekend'
]

X = df[features]
y = df['traffic_status']

# %%
df = df.sort_values("date_time")

split_index = int(len(df) * 0.8)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

X_train = train[features]
y_train = train['traffic_status']

X_test = test[features]
y_test = test['traffic_status']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

categorical_features = ['weather_main']

preprocessor = ColumnTransformer(
    transformers=[
        ('encoder', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 100,random_state = 42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', RandomForestClassifier(
        n_estimators=200,
        random_state=42
    ))
])

# %%
from sklearn.pipeline import Pipeline
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['weather_main'])])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = pipeline.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9306088580022819
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      5482
#            1       0.90      0.94      0.92      4159
#
#     accuracy                           0.93      9641
#    macro avg       0.93      0.93      0.93      9641
# weighted avg       0.93      0.93      0.93      9641

# %%
train_pred = pipeline.predict(X_train)

print("Train Accuracy:", accuracy_score(y_train, train_pred))
print("Test Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy: 0.9995332313357363
# Test Accuracy: 0.9306088580022819

# %%
model = pipeline.named_steps['model']

importances = model.feature_importances_

feature_names = pipeline.named_steps['preprocessing'].get_feature_names_out()

importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
}).sort_values(by='importance', ascending=False)

importance_df.head(10)
# Out:
#                          feature  importance
# 15               remainder__hour    0.735714
# 11               remainder__temp    0.125034
# 17         remainder__is_weekend    0.075103
# 16              remainder__month    0.027043
# 12         remainder__clouds_all    0.023031
# 1   encoder__weather_main_Clouds    0.003327
# 0    encoder__weather_main_Clear    0.001697
# 5     encoder__weather_main_Mist    0.001635
# 13           remainder__rain_1hr    0.001461
# 6     encoder__weather_main_Rain    0.001446

# %%
import joblib
joblib.dump(pipeline, "traffic_analysis.pkl")
# Out:
# ['traffic_analysis.pkl']

# %%
df["traffic_status"].value_counts()
# Out:
# traffic_status
# 0    27265
# 1    20939
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[5055  427]
#  [ 242 3917]]

# %%
df["traffic_volume"].describe
# Out:
# <bound method NDFrame.describe of 0        5545
# 1        4516
# 2        4767
# 3        5026
# 4        4918
#          ...
# 48199    3543
# 48200    2781
# 48201    2159
# 48202    1450
# 48203     954
# Name: traffic_volume, Length: 48204, dtype: int64>
